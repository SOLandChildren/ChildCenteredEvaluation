# %% [markdown]
# ## Opening files

# %%
import pandas as pd

# %%
# queries

query_df = pd.read_xml("../data/kid-friend-en/en/inputs/topics.xml")
query_df.drop_duplicates(inplace=True, ignore_index=True)
query_df = query_df.rename({"number":"qid"}, axis=1)
query_df["query"] = ["".join([x if x.isalnum() else " " for x in query]) for query in query_df["query"]] # removing punctuations
query_df["qid"] = query_df["qid"].astype(str)
query_df.to_csv("../data/kid-friend-en/en/inputs/topics.csv", index=False)
query_df.head()
# Out:
#   qid          query       category  \
# 0   1            BTS  entertainment
# 1   2  BTS Bias Quiz  entertainment
# 2   3      BTS merch  entertainment
# 3   4   BTS Jungkook  entertainment
# 4   5      Minecraft  entertainment
#
#                                          description  \
# 0         Who are BTS? Where can I find their music?
# 1  Which band member suits me best? Which band me...
# 2     official BTS merch page and authorized sellers
# 3  Who is Jungkook? What does he like? What does ...
# 4  What is Minecraft? Where can I play it? Let's ...
#
#                                            narrative
# 0  Relevant documents for this request should inc...
# 1  Relevant documents include kid-friendly conten...
# 2  Relevant documents redirect to fan articles of...
# 3  Relevant documents contain information about J...
# 4  Relevant documents contain information about t...

# %%
# graded topical relevance

with open("../data/kid-friend-en/en/qrels/qrels-relevance.txt", "r") as f_qrel:
    lines= f_qrel.readlines()

qrels = []
for line in lines:
    qid, q0, docno, relevance = line.split(" ")
    qid = int(qid)
    relevance = int(relevance)
    qrels.append([qid, q0, docno, relevance])

qrels_df = pd.DataFrame(qrels, columns=["qid", "q0", "docno", "relevance"])
qrels_df["qid"] = qrels_df["qid"].astype(str)
print(len(qrels_df))
qrels_df.drop_duplicates(inplace=True, ignore_index=True)
print(len(qrels_df))
# Out:
# 2303
# 2303

# %%
qrels_df = qrels_df.drop_duplicates(subset=["qid", "docno"], ignore_index=True, keep=False) # dropping qrels which have multiple relavances for a given (qid, docno) pair
len(qrels_df)
# Out:
# 2303

# %%
qrels_df.to_csv("../data/kid-friend-en/en/qrels/qrels-relevance-graded.csv", index=False)
qrels_df.head()
# Out:
#   qid q0                             docno  relevance
# 0   1  0  77cdd0f6c3b04b5bbe79fac37c2ae63b          0
# 1   1  0  c8a2aa042145402a8c180ca6f467c575          1
# 2   1  0  d82e5e4f531841d49bcd6fe7bd8cdf8f          0
# 3   1  0  c8e3ba8d611441bebaf146001171af3a          1
# 4   1  0  44d7a109cd554b1cb44d2c3867ff7040          1

# %%
# binary topical relevance

qrels_df["relevance"] = [int(rel > 0) for rel in qrels_df["relevance"]]
qrels_df.to_csv("../data/kid-friend-en/en/qrels/qrels-relevance-binary.csv", index=False)
qrels_df.head()
# Out:
#   qid q0                             docno  relevance
# 0   1  0  77cdd0f6c3b04b5bbe79fac37c2ae63b          0
# 1   1  0  c8a2aa042145402a8c180ca6f467c575          1
# 2   1  0  d82e5e4f531841d49bcd6fe7bd8cdf8f          0
# 3   1  0  c8e3ba8d611441bebaf146001171af3a          1
# 4   1  0  44d7a109cd554b1cb44d2c3867ff7040          1

# %%
qrels_df.dtypes
# Out:
# qid          object
# q0           object
# docno        object
# relevance     int64
# dtype: object

# %%
query_df.dtypes
# Out:
# qid            object
# query          object
# category       object
# description    object
# narrative      object
# dtype: object

# %% [markdown]
# ## Adding more document features

# %% [markdown]
# ### Readability

# %%
# adding readability (spache-allen) scores of documents

import json
import pandas as pd
from spache_allen.formula import spache_allen
from tqdm.notebook import tqdm

lines = []
with open(r'../data/kid-friend-en/en/inputs/documents.jsonl') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
corpus = pd.DataFrame(line_dicts)
corpus.drop_duplicates(inplace=True,ignore_index=True)
corpus["readability"] = [spache_allen(text) for text in tqdm(corpus["main_content"], total=len(corpus))]
corpus.to_csv("../data/kid-friend-en/en/inputs/documents.csv", index=False)
print(len(corpus))
corpus
# Out:
#   0%|          | 0/2385 [00:00<?, ?it/s]
#
#
#   0%|          | 6/2385 [00:00<00:43, 54.48it/s]
#
#
#   1%|          | 12/2385 [00:00<00:44, 53.03it/s]
#
#
#   1%|          | 18/2385 [00:00<00:45, 52.35it/s]
#
#
#   1%|          | 25/2385 [00:00<00:45, 51.56it/s]
#
#
#   1%|▏         | 33/2385 [00:00<00:39, 59.14it/s]
#
#
#   2%|▏         | 42/2385 [00:00<00:35, 65.17it/s]
#
#
#   2%|▏         | 49/2385 [00:00<00:49, 47.33it/s]
#
#
#   2%|▏         | 55/2385 [00:01<01:03, 36.62it/s]
#
#
#   3%|▎         | 60/2385 [00:01<01:08, 33.70it/s]
#
#
#   3%|▎         | 64/2385 [00:01<01:14, 31.15it/s]
#
#
#   3%|▎         | 68/2385 [00:01<01:23, 27.87it/s]
#
#
#   3%|▎         | 72/2385 [00:01<01:22, 27.92it/s]
#
#
#   3%|▎         | 75/2385 [00:02<01:34, 24.53it/s]
#
#
#   3%|▎         | 79/2385 [00:02<01:41, 22.72it/s]
#
#
#   3%|▎         | 83/2385 [00:02<01:30, 25.46it/s]
#
#
#   4%|▎         | 86/2385 [00:02<01:44, 21.91it/s]
#
#
#   4%|▍         | 93/2385 [00:02<01:19, 28.95it/s]
#
#
#   4%|▍         | 99/2385 [00:02<01:05, 35.12it/s]
#
#
#   4%|▍         | 103/2385 [00:02<01:10, 32.22it/s]
#
#
#   5%|▍         | 109/2385 [00:03<01:02, 36.65it/s]
#
#
#   5%|▍         | 115/2385 [00:03<00:54, 42.01it/s]
#
#
#   5%|▌         | 120/2385 [00:03<00:54, 41.89it/s]
#
#
#   5%|▌         | 125/2385 [00:03<00:54, 41.18it/s]
#
#
#   5%|▌         | 130/2385 [00:03<00:56, 39.76it/s]
#
#
#   6%|▌         | 136/2385 [00:03<00:53, 42.32it/s]
#
#
#   6%|▌         | 141/2385 [00:03<00:53, 41.80it/s]
#
#
#   6%|▌         | 148/2385 [00:03<00:45, 48.86it/s]
#
#
#   6%|▋         | 154/2385 [00:04<00:55, 40.50it/s]
#
#
#   7%|▋         | 160/2385 [00:04<00:50, 43.71it/s]
#
#
#   7%|▋         | 165/2385 [00:04<00:50, 43.65it/s]
#
#
#   7%|▋         | 170/2385 [00:04<00:53, 41.40it/s]
#
#
#   7%|▋         | 175/2385 [00:04<00:57, 38.64it/s]
#
#
#   8%|▊         | 180/2385 [00:04<01:02, 35.15it/s]
#
#
#   8%|▊         | 186/2385 [00:04<00:55, 39.98it/s]
#
#
#   8%|▊         | 191/2385 [00:05<00:56, 38.97it/s]
#
#
#   8%|▊         | 196/2385 [00:05<00:59, 36.87it/s]
#
#
#   8%|▊         | 200/2385 [00:05<00:59, 36.98it/s]
#
#
#   9%|▊         | 207/2385 [00:05<00:50, 43.37it/s]
#
#
#   9%|▉         | 213/2385 [00:05<00:47, 46.12it/s]
#
#
#   9%|▉         | 220/2385 [00:05<00:43, 50.05it/s]
#
#
#   9%|▉         | 226/2385 [00:05<00:41, 52.01it/s]
#
#
#  10%|▉         | 232/2385 [00:05<00:42, 50.96it/s]
#
#
#  10%|▉         | 238/2385 [00:06<00:47, 45.21it/s]
#
#
#  10%|█         | 243/2385 [00:06<00:58, 36.49it/s]
#
#
#  10%|█         | 248/2385 [00:06<00:54, 39.26it/s]
#
#
#  11%|█         | 253/2385 [00:06<00:57, 37.40it/s]
#
#
#  11%|█         | 258/2385 [00:06<00:52, 40.17it/s]
#
#
#  11%|█         | 263/2385 [00:06<01:20, 26.29it/s]
#
#
#  11%|█         | 267/2385 [00:07<01:29, 23.54it/s]
#
#
#  11%|█▏        | 271/2385 [00:07<01:22, 25.57it/s]
#
#
#  12%|█▏        | 275/2385 [00:07<01:18, 26.97it/s]
#
#
#  12%|█▏        | 279/2385 [00:07<01:18, 26.86it/s]
#
#
#  12%|█▏        | 283/2385 [00:07<01:11, 29.55it/s]
#
#
#  12%|█▏        | 287/2385 [00:07<01:25, 24.42it/s]
#
#
#  12%|█▏        | 290/2385 [00:08<01:22, 25.45it/s]
#
#
#  12%|█▏        | 293/2385 [00:08<01:53, 18.39it/s]
#
#
#  12%|█▏        | 296/2385 [00:08<01:43, 20.22it/s]
#
#
#  13%|█▎        | 299/2385 [00:08<02:05, 16.64it/s]
#
#
#  13%|█▎        | 304/2385 [00:08<01:37, 21.35it/s]
#
#
#  13%|█▎        | 308/2385 [00:08<01:23, 24.75it/s]
#
#
#  13%|█▎        | 311/2385 [00:09<01:34, 21.95it/s]
#
#
#  13%|█▎        | 315/2385 [00:09<01:21, 25.29it/s]
#
#
#  13%|█▎        | 320/2385 [00:09<01:08, 30.01it/s]
#
#
#  14%|█▎        | 324/2385 [00:09<01:23, 24.66it/s]
#
#
#  14%|█▍        | 328/2385 [00:09<01:14, 27.43it/s]
#
#
#  14%|█▍        | 332/2385 [00:09<01:14, 27.57it/s]
#
#
#  14%|█▍        | 336/2385 [00:09<01:09, 29.66it/s]
#
#
#  14%|█▍        | 340/2385 [00:10<01:41, 20.14it/s]
#
#
#  14%|█▍        | 344/2385 [00:10<01:27, 23.44it/s]
#
#
#  15%|█▍        | 347/2385 [00:10<01:43, 19.78it/s]
#
#
#  15%|█▍        | 350/2385 [00:10<01:51, 18.18it/s]
#
#
#
#  84%|████████▍ | 2002/2385 [00:57<00:08, 46.48it/s]
#
#
#  84%|████████▍ | 2009/2385 [00:57<00:07, 50.74it/s]
#
#
#  84%|████████▍ | 2015/2385 [00:58<00:07, 48.74it/s]
#
#
#  85%|████████▍ | 2021/2385 [00:58<00:07, 49.41it/s]
#
#
#  85%|████████▍ | 2027/2385 [00:58<00:07, 46.45it/s]
#
#
#  85%|████████▌ | 2034/2385 [00:58<00:06, 51.08it/s]
#
#
#  86%|████████▌ | 2041/2385 [00:58<00:06, 54.53it/s]
#
#
#  86%|████████▌ | 2047/2385 [00:58<00:06, 53.33it/s]
#
#
#  86%|████████▌ | 2055/2385 [00:58<00:05, 57.74it/s]
#
#
#  86%|████████▋ | 2062/2385 [00:58<00:05, 59.51it/s]
#
#
#  87%|████████▋ | 2069/2385 [00:59<00:06, 52.36it/s]
#
#
#  87%|████████▋ | 2077/2385 [00:59<00:05, 55.77it/s]
#
#
#  87%|████████▋ | 2083/2385 [00:59<00:05, 54.88it/s]
#
#
#  88%|████████▊ | 2089/2385 [00:59<00:06, 48.83it/s]
#
#
#  88%|████████▊ | 2095/2385 [00:59<00:05, 50.00it/s]
#
#
#  88%|████████▊ | 2101/2385 [00:59<00:05, 49.31it/s]
#
#
#  88%|████████▊ | 2108/2385 [00:59<00:05, 53.87it/s]
#
#
#  89%|████████▊ | 2114/2385 [00:59<00:05, 50.98it/s]
#
#
#  89%|████████▉ | 2120/2385 [01:00<00:06, 42.72it/s]
#
#
#  89%|████████▉ | 2125/2385 [01:00<00:07, 36.91it/s]
#
#
#  89%|████████▉ | 2130/2385 [01:00<00:06, 39.54it/s]
#
#
#  90%|████████▉ | 2135/2385 [01:00<00:06, 41.33it/s]
#
#
#  90%|████████▉ | 2142/2385 [01:00<00:05, 47.15it/s]
#
#
#  90%|█████████ | 2147/2385 [01:00<00:05, 42.35it/s]
#
#
#  90%|█████████ | 2154/2385 [01:00<00:04, 46.74it/s]
#
#
#  91%|█████████ | 2159/2385 [01:01<00:05, 42.41it/s]
#
#
#  91%|█████████ | 2164/2385 [01:01<00:05, 42.67it/s]
#
#
#  91%|█████████ | 2170/2385 [01:01<00:04, 44.34it/s]
#
#
#  91%|█████████ | 2176/2385 [01:01<00:04, 46.76it/s]
#
#
#  91%|█████████▏| 2181/2385 [01:01<00:04, 45.06it/s]
#
#
#  92%|█████████▏| 2188/2385 [01:01<00:04, 48.00it/s]
#
#
#  92%|█████████▏| 2195/2385 [01:01<00:03, 52.94it/s]
#
#
#  92%|█████████▏| 2201/2385 [01:01<00:03, 51.80it/s]
#
#
#  93%|█████████▎| 2207/2385 [01:02<00:03, 46.40it/s]
#
#
#  93%|█████████▎| 2214/2385 [01:02<00:03, 52.03it/s]
#
#
#  93%|█████████▎| 2221/2385 [01:02<00:02, 56.37it/s]
#
#
#  93%|█████████▎| 2228/2385 [01:02<00:02, 59.92it/s]
#
#
#  94%|█████████▎| 2235/2385 [01:02<00:02, 54.19it/s]
#
#
#  94%|█████████▍| 2242/2385 [01:02<00:02, 58.10it/s]
#
#
#  94%|█████████▍| 2249/2385 [01:02<00:02, 53.80it/s]
#
#
#  95%|█████████▍| 2256/2385 [01:02<00:02, 55.84it/s]
#
#
#  95%|█████████▍| 2262/2385 [01:03<00:02, 51.10it/s]
#
#
#  95%|█████████▌| 2269/2385 [01:03<00:02, 53.65it/s]
#
#
#  95%|█████████▌| 2275/2385 [01:03<00:02, 53.10it/s]
#
#
#  96%|█████████▌| 2281/2385 [01:03<00:02, 51.86it/s]
#
#
#  96%|█████████▌| 2287/2385 [01:03<00:01, 49.12it/s]
#
#
#  96%|█████████▌| 2292/2385 [01:03<00:03, 27.59it/s]
#
#
#  96%|█████████▋| 2296/2385 [01:04<00:03, 26.11it/s]
#
#
#  97%|█████████▋| 2302/2385 [01:04<00:02, 30.37it/s]
#
#
#  97%|█████████▋| 2307/2385 [01:04<00:02, 33.27it/s]
#
#
#  97%|█████████▋| 2315/2385 [01:04<00:01, 43.02it/s]
#
#
#  97%|█████████▋| 2323/2385 [01:04<00:01, 50.61it/s]
#
#
#  98%|█████████▊| 2329/2385 [01:04<00:01, 43.70it/s]
#
#
#  98%|█████████▊| 2335/2385 [01:04<00:01, 41.19it/s]
#
#
#  98%|█████████▊| 2340/2385 [01:04<00:01, 42.97it/s]
#
#
#  98%|█████████▊| 2345/2385 [01:05<00:00, 42.58it/s]
#
#
#  99%|█████████▊| 2350/2385 [01:05<00:00, 41.67it/s]
#
#
#  99%|█████████▊| 2355/2385 [01:05<00:00, 40.28it/s]
#
#
#  99%|█████████▉| 2360/2385 [01:05<00:00, 37.32it/s]
#
#
#  99%|█████████▉| 2364/2385 [01:05<00:00, 37.79it/s]
#
#
#  99%|█████████▉| 2368/2385 [01:05<00:00, 37.05it/s]
#
#
#  99%|█████████▉| 2372/2385 [01:05<00:00, 36.23it/s]
#
#
# 100%|█████████▉| 2376/2385 [01:06<00:00, 29.60it/s]
#
#
# 100%|█████████▉| 2380/2385 [01:06<00:00, 30.31it/s]
#
#
# 100%|██████████| 2385/2385 [01:06<00:00, 35.85it/s]
# 2385
#                                  docno  \
# 0     6e421f1539b1457b853712d81be87743
# 1     1539268e3f1d41c9abcaa277b23f51d9
# 2     93689ea1c0ec4272b41d7b259cb47890
# 3     2e4321c5105840c8b6612f87dc4aba13
# 4     3d21474fff4e406c9db2984d5edf647b
# ...                                ...
# 2380  648909aa33704dee80d34cda654ed0e3
# 2381  caa7c7203c2049f9a5257439f5e7b822
# 2382  3cf211d4b8fd4884bfbb4b3c46305c8b
# 2383  bf691cd32f2f47a98b8f6673dd47ea18
# 2384  748731d015c649e589f9fee65262bce4
#
#                                                 snippet  \
# 0     WEBBTS (also Bangtan Boys; Korean: 방탄소년단 Bangt...
# 1     WEBMusic video by BTS performing Dynamite. (C)...
# 2     Biography BTS is a Grammy-nominated South Kore...
# 3     WEBBTS (Korean: 방탄소년단; RR: Bangtan Sonyeondan;...
# 4     WEBTo avoid this, cancel and sign in to YouTub...
# ...                                                 ...
# 2380  Sep 27, 2021 -\nWho likes school???????\n...\n...
# 2381  Mar 8, 2021 -\nWho knows or likes the music of...
# 2382  Mar 8, 2021 -\nWho knows or likes DSDS?\n... t...
# 2383  Apr 1, 2022 - ...  wand, Severus walked slowly...
# 2384  Oct 16, 2023 - ...\nHow do I tell my girlfrien...
#
#                                                   title  \
# 0                                BTS (band) - Wikipedia
# 1                           Before you go on to YouTube
# 2                           Before you go on to YouTube
# 3                                       BTS - Wikipedia
# 4     BTS (방탄소년단) 'Yet To Come (The Most Beautiful M...
# ...                                                 ...
# 2380              Who likes school??????? | Page strong
# 2381  Who knows or likes the music of Sarah Lombardi...
# 2382           Who knows or likes DSDS??? | Page strong
# 2383  Severus Snape meets his daughter ( Chapter 1 T...
# 2384  How do I tell my girlfriend to call me Noah? |...
#
#                                            main_content  readability
# 0     BTS (also Bangtan Boys; Korean: 방탄소년단 Bangtan ...     6.714078
# 1     YouTube\nA Google company\n\nBefore you go on ...     7.757287
# 2     YouTube\nA Google company\n\nBefore you go on ...     7.757287
# 3     BTS (Korean방탄소년단; RRBangtan Sonyeondan; lit. B...     8.258022
# 4     So, Who is missing BTS badly. Let's stay stron...     6.958174
# ...                                                 ...          ...
# 2380  Who likes school???????\n\nWho likes school???...     5.494769
# 2381  Who knows or likes the music of Sarah Lombardi...     6.481945
# 2382  Who knows or likes DSDS???\n\nWho knows or lik...     4.946886
# 2383  Severus Snape meets his daughter ( Chapter 1 H...     4.063169
# 2384  How do I tell my girlfriend to call me Noah?\n...     4.555605
#
# [2385 rows x 5 columns]

# %%
import pandas as pd

df = pd.read_csv("../data/kid-friend-en/en/inputs/documents.csv")
len(df)
# Out:
# 2385

# %%
import pandas as pd
import json

lines = []
with open(r'../data/kid-friend-en/en/inputs/documents.jsonl') as f:
    lines = f.read().splitlines()

line_dicts = [json.loads(line) for line in lines]
corpus = pd.DataFrame(line_dicts)
corpus.drop_duplicates(inplace=True,ignore_index=True)
len(corpus.loc[corpus["main_content"]==""]), len(corpus.loc[(corpus["main_content"]=="")&(corpus["snippet"]=="")]), len(corpus.loc[(corpus["main_content"]=="")&(corpus["snippet"]=="")&(corpus["title"]=="")])
# Out:
# (187, 15, 7)

# %%
corpus_df = pd.read_csv("../data/kid-friend-en/en/inputs/documents.csv")
corpus_df.loc[(corpus_df["readability"]<0)&(corpus_df["main_content"].isna()==False)]
# Out:
#                                  docno snippet                   title  \
# 1815  6631c7692a2148beae63c0bdb6c82e70     NaN  Like a leaping dolphin
#
#                          main_content  readability
# 1815  icon-angle icon-bars icon-times         -1.0

# %%
corpus_df.loc[(corpus_df["readability"]<0)]
# Out:
#                                  docno  \
# 5     37d53c33110a4231807e71e377f08377
# 6     aa31a4d64bbf4accb37f37762307634f
# 30    8180b99992b34e2ab0813e50222884ba
# 34    3888836f228d4701913acdd11c688f86
# 38    c8d52a8560894eb4affaa083af21edbb
# ...                                ...
# 2256  3e606883584d44e29dc248a25e71fe86
# 2308  162c880249254e06b976f5b4d63c9601
# 2311  06180d11fdb844f28157d0814476ca2c
# 2312  c573e2778ac74ecd8d9be00790235fba
# 2314  dccf8df6998c400b8a706469586787b8
#
#                                                 snippet  \
# 5     Discover BTS, the global superstars of K-pop, ...
# 6                          The official website for BTS
# 30    Minecraft is a sandbox game where you can crea...
# 34    WEBBuild with sculk, mud, and mangrove wood. T...
# 38    WEB4 days ago - Minecraft Java 1.21.1 Released...
# ...                                                 ...
# 2256   Profession: vet - Sure, everyone wants to hel...
# 2308  May 13, 2024 - ...\nWhat are the reasons for a...
# 2311  Dec 10, 2018 -\nIn this article, children lear...
# 2312  Nov 21, 2018 -\nTemperatures on our planet are...
# 2314  Oct 31, 2022 -\nClimate change affects us all ...
#
#                                                   title main_content  \
# 5                                    BTS | BIGHIT MUSIC          NaN
# 6                                    BTS | BIGHIT MUSIC          NaN
# 30                                                  NaN          NaN
# 34    The Wild Update: Craft Your Path - Official Mi...          NaN
# 38                                                  NaN          NaN
# ...                                                 ...          ...
# 2256                                                NaN          NaN
# 2308                       War in Ukraine | Seitenstark          NaN
# 2311                       Climate change | Seitenstark          NaN
# 2312  Climate change and climate protection | Seiten...          NaN
# 2314  Interactive whiteboard: Climate change | Seite...          NaN
#
#       readability
# 5            -1.0
# 6            -1.0
# 30           -1.0
# 34           -1.0
# 38           -1.0
# ...           ...
# 2256         -1.0
# 2308         -1.0
# 2311         -1.0
# 2312         -1.0
# 2314         -1.0
#
# [188 rows x 5 columns]

# %% [markdown]
# ### Objectivity

# %% [markdown]
# ### Educational Alignment

# %% [markdown]
# ## Creating other versions of ground truth

# %%
# # binary readability relevance: all docs paired with each qid

# query_df = pd.read_csv("../kid-friend-en/en/inputs/topics.csv")
# corpus = pd.read_csv("../kid-friend-en/en/inputs/documents.csv")
# qids = query_df["qid"].unique()

# read_qrels = []
# for qid in qids:
#     for _, row in corpus.iterrows():
#         if row["readability"] < 0: # removing query-doc pairs where the readability score is invalid (i.e., the score < 0)
#             continue
#         read_qrels.append([qid, "q0", row["docno"], int(int(row["readability"]) <= 4)])

# readability_qrels = pd.DataFrame(read_qrels, columns=["qid", "q0", "docno", "relevance"])
# readability_qrels.to_csv("../kid-friend-en/en/qrels/qrels-readability-alldocs.csv", index=False)
# readability_qrels.head()

# %%
# assert len(query_df)*len(corpus.loc[corpus["readability"]>0]) == len(readability_qrels)

# %% [markdown]
# ### Relevance + Readability

# %%
# binary readability relevance: same query-doc pairs as qrels-relevance-binary.txt 
# query-doc pair assigned 1 if relevant and readable; 0 otherwise

from tqdm import tqdm
import pandas as pd

# nltk.download('all', halt_on_error=False)
corpus = pd.read_csv("../data/kid-friend-en/en/inputs/documents.csv")
qrels_df = pd.read_csv("../data/kid-friend-en/en/qrels/qrels-relevance-binary.csv")
read_relevance = []
issue_docs = []

for _, row in tqdm(qrels_df.iterrows(), total=len(qrels_df)):
    qid = row["qid"]
    docid = row["docno"]
    relevance = row["relevance"]
    readability = list(corpus.loc[corpus["docno"]==docid]["readability"])[0]
    if readability < 0: # removing query-doc pairs where the readability score is invalid (i.e., the score < 0)
        issue_docs.append(docid)
        continue
    else:
        read_relevance.append([qid, "q0", docid, relevance*int(int(readability)<=4)])

qrels_readability_df = pd.DataFrame(read_relevance, columns=["qid", "q0", "docno", "relevance"])
qrels_readability_df.to_csv("../data/kid-friend-en/en/qrels/qrels-readability-binary.csv", index=False)
qrels_readability_df
# Out:
#   0%|          | 0/2303 [00:00<?, ?it/s]
#
#
#
#
#
#  13%|█▎        | 289/2303 [00:00<00:00, 2883.96it/s]
#
#
#
#
#
#  26%|██▌       | 593/2303 [00:00<00:00, 2974.66it/s]
#
#
#
#
#
#  39%|███▉      | 902/2303 [00:00<00:00, 3025.88it/s]
#
#
#
#
#
#  53%|█████▎    | 1210/2303 [00:00<00:00, 3044.29it/s]
#
#
#
#
#
#  67%|██████▋   | 1532/2303 [00:00<00:00, 3104.99it/s]
#
#
#
#
#
#  80%|████████  | 1843/2303 [00:00<00:00, 3073.86it/s]
#
#
#
#
#
# 100%|██████████| 2303/2303 [00:00<00:00, 3051.03it/s]
#       qid  q0                             docno  relevance
# 0       1  q0  77cdd0f6c3b04b5bbe79fac37c2ae63b          0
# 1       1  q0  c8a2aa042145402a8c180ca6f467c575          0
# 2       1  q0  c8e3ba8d611441bebaf146001171af3a          0
# 3       1  q0  58e44787b87844e4a968d6eb1edf94bd          0
# 4       1  q0  f2ef0e00fdcf42cfa9e4d364c0282379          1
# ...   ...  ..                               ...        ...
# 2133   50  q0  b7646dcb4b134afbacbe9a61a4ef914e          0
# 2134   50  q0  bc5f268885cb41379f06ced62f96adbb          0
# 2135   50  q0  c5840e5e858d4baa97ecf216dda4e6c3          0
# 2136   50  q0  bf5f2ac9b4454a79bd6848f10314bbee          0
# 2137   50  q0  e4adf192c95d4114a131174f6df262dd          1
#
# [2138 rows x 4 columns]

# %%
assert (len(qrels_df)-len(qrels_readability_df))==len(issue_docs)

doc_issues = [x for x in list(qrels_df["docno"].unique()) if x not in list(qrels_readability_df["docno"].unique())]
print(len(doc_issues), len(set(issue_docs)))
for docno in doc_issues:
    print(docno, list(corpus.loc[corpus["docno"]==docno]["readability"])[0])
# Out:
# 155 155
# d82e5e4f531841d49bcd6fe7bd8cdf8f -1.0
# 44d7a109cd554b1cb44d2c3867ff7040 -1.0
# 0b9c61100ede42af9877beadb1efb5d7 -1.0
# 37d53c33110a4231807e71e377f08377 -1.0
# 59f02513ed164167acd899288008a031 -1.0
# aa31a4d64bbf4accb37f37762307634f -1.0
# 1b85bcbd61624d669d6c0acac9ad4b98 -1.0
# 2e54ded87f644883a3584a0243c51e20 -1.0
# 86ab497754404406b7a1ed3c03ce9cfb -1.0
# 69153b48fc8a49d0b25288ff437c3710 -1.0
# 45b35de6fc3c4e18a022f3da33902aee -1.0
# 956d50deed2443debe6157dc6aa46915 -1.0
# d40775523c5a4b2497f6489c872265c6 -1.0
# 48515a541041417f851fbd64fe9c9680 -1.0
# 8228edeaddca434d8f795450593fa982 -1.0
# 8180b99992b34e2ab0813e50222884ba -1.0
# 44cb123878434faea075424720f89016 -1.0
# 7d8990896c4840d9a27d90d4e0474a0f -1.0
# ab66bf5a07d84c52a558466115cce919 -1.0
# 4544b16682624a029b5f0ddda339b550 -1.0
# 1d9ed000f28a4f2c94bf7c72f0204c33 -1.0
# a442546344234166b6ddf11fa82cda4c -1.0
# 19f4141c080043c680ea604749532cc3 -1.0
# 71f6b7b3ad2d4f689eec93c8e3e998ea -1.0
# 02c82fe2db8746ac8e6789efac91e823 -1.0
# 5ea8923290e94f09a08e066f5f95660f -1.0
# c92fca209161431c96a5529f6fab637e -1.0
# 8e71f0f4bffe46c3ba6ff783ccb663e8 -1.0
# 583295b60d5f4fb5846716aaf4bcb2b7 -1.0
# df3b3fe404544c928a1df40b642a98c9 -1.0
# 0495b593564a41bebb1dc971070413e4 -1.0
# 2c147427b6de4e3f91d49de27acd42e5 -1.0
# de97a08d98114112b33ed9e28c4acbb7 -1.0
# a6801523cf40467797fe14329a4f2397 -1.0
# c2a251b89e224009ac1765bf4dd1d395 -1.0
# 0b7268560a55488996abb9f7ad44c62c -1.0
# 9dd3012a423a41f4a3dc4f3521a5b1a5 -1.0
# e04c90cf4abd41b4a6a129c7a0da43af -1.0
# 01c0ff1de9414afaa2319f436257aaa3 -1.0
# db2c3a6083564168ba7e5ae615ecbd9d -1.0
# 8125ae155e0e4ea79e1859d3e3916279 -1.0
# 8efb8f3389384505ad6cee4096c8fea8 -1.0
# c68cde8055474674806606a728d8f45e -1.0
# abe5e1c44bcf4e13aac29a73033df812 -1.0
# 3e606883584d44e29dc248a25e71fe86 -1.0
# c5ae52e73e074098ba049a1af466ec1b -1.0

# %%
# # graded readability labels (zuccon formula): same query-doc pairs as qrels-relevance-binary.csv

# from tqdm.notebook import tqdm
# import pandas as pd
# from utils import get_graded_readability_rel_zuccon

# # nltk.download('all', halt_on_error=False)
# corpus = pd.read_csv("../kid-friend-en/en/inputs/documents.csv")
# qrels_df = pd.read_csv("../kid-friend-en/en/qrels/qrels-relevance-binary.csv")
# qrels_readability = qrels_df
# read_relevance = []

# for _, row in tqdm(qrels_readability.iterrows(), total=len(qrels_readability)):
#     docid = row["docno"]
#     readability = list(corpus.loc[corpus["docno"]==docid]["readability"])[0]
#     read_relevance.append(readability)

# qrels_df["read_relevance"] = read_relevance
# qrels_df["read_relevance_label"] = get_graded_readability_rel_zuccon(qrels_df["read_relevance"], threshold=4)
# qrels_df.drop(["relevance", "read_relevance"], axis=1, inplace=True)
# qrels_df = qrels_df.rename({"read_relevance_label": "relevance"}, axis=1)
# qrels_df.to_csv("../kid-friend-en/en/qrels/qrels-readability-graded.csv", index=False)
# qrels_df

# %%
# qrels_df.loc[qrels_df["relevance"].isna()] # checking if any doc had invalid readability score

# %%
# qrels_df = qrels_df.dropna(subset=["relevance"]) # remove query-doc pairs where the doc had an invalid readability score
# qrels_df.to_csv("../kid-friend-en/en/qrels/qrels-readability-graded.csv", index=False)
# qrels_df

# %% [markdown]
# ### Objectivity + Relevance

# %% [markdown]
# ### Educational Alignment + Relevance
